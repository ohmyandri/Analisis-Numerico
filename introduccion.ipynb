# %% [markdown]
# Libreria necesaria para lo que haremos

# %%
import numpy as np # type: ignore

np.cos(0)
# Out:
# np.float64(1.0)

# %% [markdown]
# Variables

# %%
x = 9
y = 3
var = x+y
print(var + 2)
# Out:
# 14

# %% [markdown]
# Condicionales

# %%
edad = int(input("¿Cual es tu edad?: "))

if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# Ciclos

# %%
for i in range(10):
    print(f"Iteracion {i+1}")

# %% [markdown]
# Listas

# %%
lista = [12, 23, 311, 41, 5]

for elemento in lista:
    print(f"El cuadrado de {elemento} es: {elemento * elemento}")

for elemento in lista:
    print(f"La raiz cuadrada de {elemento} es: {elemento**(1/2)}")
