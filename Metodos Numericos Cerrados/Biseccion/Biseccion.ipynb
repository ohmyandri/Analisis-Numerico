# %% [markdown]
# Metodo de Biseccion

# %% [markdown]
# Funcion a utilizar
#
# $$
# f(x) = e^x + x - 2
# $$

# %%
def f(x):
    return ((np.exp(x)) + x - 2)

# %% [markdown]
# Funcion para obtener Xm
# $$x_m = \frac{a + b}{2}$$

# %%
def fXm(a, b):
    return (a+b)/2

# %% [markdown]
# Funcion del metodo numerico

# %%
def metodoNumerico(a, b): #pasamos valores iniciales
    xa = a
    for i in range(1, maxIter+1):
        # print(f"Iteracion numero {i}")
        #calculo de xm
        Xm = fXm(a, b)
        error = abs(xa - Xm)
        xa = Xm

        if(f(a) * f(Xm) < 0): #hay cambio de signo, por tanto, la raiz esta entre esos
            # print("El cambio de signo esta entre f(a) y f(Xm)")
            b = Xm

        elif(f(b) * f(Xm) < 0): #hay cambio de signo, por tanto, la raiz esta entre esos
            # print("El cambio de signo esta entre f(b) y f(Xm)")
            a = Xm
        
        # else:
        #     print(f"La raiz es Xm con valor de: {Xm}")
        #     break

        if(error < epsilon):
            break
    print(f"Error: {error}")
    print(f"La raiz aproximada en la iteracion es Xm con valor de: {Xm}")

# %% [markdown]
# Condiciones de Parada

# %%
#Condicion de parada
epsilon = 1e-10
maxIter = 100

#Numero de cifras decimales
cifrasDecimales = 5
